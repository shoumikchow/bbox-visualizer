# %% [markdown]
# # Single Object Example

# %%
import json

import cv2
import matplotlib.pyplot as plt

import bbox_visualizer as bbv

img = cv2.imread("../images/source_single.jpg")
annotation = json.load(open("../images/source_single.json"))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
points = annotation["shapes"][0]["points"]
label = annotation["shapes"][0]["label"]

print(f"Points box: {points}, {type(points)}")
print(f"Label box: {label}, {type(label)}")
# Out:
# Points box: [[1348, 860], [1617, 1758]], <class 'list'>
# Label box: person, <class 'str'>

# %% [markdown]
# **Prepare points to input bbox**

# %%
(xmin, ymin), (xmax, ymax) = points
print((xmin, ymin), (xmax, ymax))
# Out:
# (1348, 860) (1617, 1758)

# %%
bbox = [xmin, ymin, xmax, ymax]
print(bbox)
# Out:
# [1348, 860, 1617, 1758]

# %% [markdown]
# **Draw box rectangle**

# %%
img_with_box = bbv.draw_rectangle(img, bbox)
print(type(img_with_box))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(img_with_box);

# %% [markdown]
# We can add a label:

# %%
img_with_box_2 = img_with_box.copy()

img_label = bbv.add_label(img_with_box, label, bbox)
print(type(img_label))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(img_label);

# %% [markdown]
# Let's adapt it to the T format:

# %%
img_T_label = bbv.add_T_label(img_with_box_2, label, bbox)
print(type(img_T_label))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(img_T_label);

# %% [markdown]
# Or if you prefer, it can be adapted to flag format:

# %%
img_flag = bbv.draw_flag_with_label(img, label, bbox)

# %%
plt.imshow(img_flag);
